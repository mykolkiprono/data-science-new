# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("/home/mike/Downloads/archive(8)/Divorce Rates.xlsx")

# %%
data.head()
# Out:
#          Country  Divorces
# 0          China   1893000
# 1  United States   1106670
# 2         Russia    685910
# 3          Japan    257475
# 4        Germany    190928

# %%
sns.countplot(data.Country)

# %%
sns.barplot(x='Country', y='Divorces',data=data)

# %%
grouped = data.groupby(data['Country'])

# %%
agg = grouped.sum()

# %%
agg.plot(kind= 'pie', figsize=(10, 5), autopct= '%1.1f%%', subplots=True)
plt.legend(loc=2)

# %%
sns.distplot(data.Divorces)

# %%
data =

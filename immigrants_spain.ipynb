# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/home/mike/Downloads/data/archive(8)/Immigration_Madrid_2021.csv",dtype={'Gender':'category','Studies':'category','Studies':'category','Nationality':'category'})

# %%
df.head()
# Out:
#    Unnamed: 0 Gender    Age      Studies           Nationality  \
# 0           0  Women  51-65      College                España
# 1           1  Women  51-65      College             Venezuela
# 2           2  Women  18-30  Pre-college              Honduras
# 3           3  Women  18-30  Pre-college             Venezuela
# 4           4  Women  18-30  Pre-college  República Dominicana
#
#   Administrative_situation Working
# 0                Community      No
# 1                      ART      No
# 2                  Refugee      No
# 3                Community      No
# 4       Community_familiar      No

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1523, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1523 entries, 0 to 1522
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1523 non-null   int64
#  1   Gender                    1523 non-null   category
#  2   Age                       1523 non-null   object
#  3   Studies                   1523 non-null   category
#  4   Nationality               1523 non-null   category
#  5   Administrative_situation  1523 non-null   object
#  6   Working                   1523 non-null   object
# dtypes: category(3), int64(1), object(3)
# memory usage: 54.3+ KB

# %%
df.groupby('Gender').get_group('Men')
# Out:
#       Unnamed: 0 Gender    Age      Studies Nationality  \
# 5              5    Men  18-30      College        Perú
# 7              7    Men  18-30  High-school     Camerún
# 20            20    Men  51-65  High-school   Nicaragua
# 26            40    Men  18-30      College   Venezuela
# 27            44    Men  18-30  Pre-college   Venezuela
# ...          ...    ...    ...          ...         ...
# 1509        1794    Men  18-30  High-school      España
# 1510        1795    Men  18-30  High-school      España
# 1514        1799    Men  18-30  Pre-college     Ecuador
# 1515        1800    Men  18-30  Pre-college     Ecuador
# 1516        1801    Men  18-30  Pre-college     Ecuador
#
#      Administrative_situation Working
# 5          Community_familiar      No
# 7                     Refugee      No
# 20                    Refugee      No
# 26                    Refugee     Yes
# 27                    Refugee     Yes
# ...                       ...     ...
# ...

# %%
df.groupby('Gender').count()
# Out:
#         Unnamed: 0   Age  Studies  Nationality  Administrative_situation  \
# Gender
# Men            459   459      459          459                       459
# Women         1064  1064     1064         1064                      1064
#
#         Working
# Gender
# Men         459
# Women      1064

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/home/mike/Downloads/data/archive(7)/water_potability.csv")

# %%
data.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
sns.countplot(data['Potability'])

# %%
pot_values = data['Potability'].value_counts()
pot_values
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %%
pot_values.plot(kind= 'pie', figsize=(10, 5), autopct= '%1.1f%%')

# %%
sns.pairplot(data)

# %%
data.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
sns.distplot(data['Conductivity'])

# %%
data.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
plt.figure(figsize=(15,15))

plt.subplot(441)
sns.distplot(data['ph'])

plt.subplot(442)
sns.distplot(data['Hardness'])

plt.subplot(443)
sns.distplot(data['Solids'])

plt.subplot(444)
sns.distplot(data['Chloramines'])

plt.subplot(445)
sns.distplot(data['Sulfate'])

plt.subplot(446)
sns.distplot(data['Conductivity'])

plt.subplot(447)
sns.distplot(data['Organic_carbon'])

plt.subplot(448)
sns.distplot(data['Trihalomethanes'])

plt.tight_layout()
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
data['Potability'] = data['Potability'].astype('category')

# %%
plt.figure(figsize=(15,15))

plt.subplot(441)
sns.violinplot(data['ph'])

plt.subplot(442)
sns.violinplot(data['Hardness'])

plt.subplot(443)
sns.violinplot(data['Solids'])

plt.subplot(444)
sns.violinplot(data['Chloramines'])

plt.subplot(445)
sns.violinplot(data['Sulfate'])

plt.subplot(446)
sns.violinplot(data['Conductivity'])

plt.subplot(447)
sns.violinplot(data['Organic_carbon'])

plt.subplot(448)
sns.violinplot(y=data['Trihalomethanes'], x=data['Potability'])

plt.tight_layout()
plt.show()

# %%
sns.heatmap(data.corr())

# %%
data.corr()
# Out:
#                        ph  Hardness    Solids  Chloramines   Sulfate  \
# ph               1.000000  0.082096 -0.089288    -0.034350  0.018203
# Hardness         0.082096  1.000000 -0.046899    -0.030054 -0.106923
# Solids          -0.089288 -0.046899  1.000000    -0.070148 -0.171804
# Chloramines     -0.034350 -0.030054 -0.070148     1.000000  0.027244
# Sulfate          0.018203 -0.106923 -0.171804     0.027244  1.000000
# Conductivity     0.018614 -0.023915  0.013831    -0.020486 -0.016121
# Organic_carbon   0.043503  0.003610  0.010242    -0.012653  0.030831
# Trihalomethanes  0.003354 -0.013013 -0.009143     0.017084 -0.030274
# Turbidity       -0.039057 -0.014449  0.019546     0.002363 -0.011187
#
#                  Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# ph                   0.018614        0.043503         0.003354  -0.039057
# Hardness            -0.023915        0.003610        -0.013013  -0.014449
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.inspection import plot_partial_dependence
from sklearn import svm

# %%
data.dropna(inplace=True)

# %%
y = data.pop('Potability').values
X = data.copy().values

# %%
from sklearn.model_selection import cross_val_score
clf = svm.SVC(kernel='linear', C=1)
scores = cross_val_score(clf, X, y, cv=5)
